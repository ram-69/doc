# %%
import numpy as np
from keras.datasets import imdb
from keras import models
from keras import layers
from keras import optimizers
from keras import losses
from keras import metrics


import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Load the data, keeping only 10,000 of the most frequently occuring words
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words = 10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 1s 0us/step

# %%
# Check the first label
train_labels[0]
# Out:
# 1

# %%
print(type([max(sequence) for sequence in train_data]))

# Find the maximum of all max indexes
max([max(sequence) for sequence in train_data])
# Out:
# <class 'list'>
# 9999

# %%
word_index = imdb.get_word_index()

# step 2: reverse word index to map integer indexes to their respective words
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

# Step 3: decode the review, mapping integer indices to words
#
# indices are off by 3 because 0, 1, and 2 are reserverd indices for "padding", "Start of sequence" and "unknown"
decoded_review = ' '.join([reverse_word_index.get(i-3, '?') for i in train_data[0]])

decoded_review
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 [==============================] - 0s 0us/step
# "? this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert ? is an amazing actor and now the same being director ? father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for ? and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also ? to the two little boy's that played the ? of norman and paul they were just brilliant children are often left out of the ? list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"

# %%
len(reverse_word_index)
# Out:
# 88584

# %%
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))    # Creates an all zero matrix of shape (len(sequences),10K)
    for i,sequence in enumerate(sequences):
        results[i,sequence] = 1                        # Sets specific indices of results[i] to 1s
    return results

# Vectorize training Data
X_train = vectorize_sequences(train_data)

# Vectorize testing Data
X_test = vectorize_sequences(test_data)

# %%
X_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
X_train.shape
# Out:
# (25000, 10000)

# %%
y_train = np.asarray(train_labels).astype('float32')
y_test  = np.asarray(test_labels).astype('float32')

# %%
model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(
    optimizer=optimizers.RMSprop(learning_rate=0.001),
    loss = losses.binary_crossentropy,
    metrics = [metrics.binary_accuracy]
)

# %%
# Input for Validation
X_val = X_train[:10000]
partial_X_train = X_train[10000:]

# Labels for validation
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
history = model.fit(
    partial_X_train,
    partial_y_train,
    epochs=20,
    batch_size=512,
    validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/20
# 30/30 [==============================] - 3s 68ms/step - loss: 0.5388 - binary_accuracy: 0.7874 - val_loss: 0.4165 - val_binary_accuracy: 0.8491
# Epoch 2/20
# 30/30 [==============================] - 1s 39ms/step - loss: 0.3243 - binary_accuracy: 0.9003 - val_loss: 0.3344 - val_binary_accuracy: 0.8646
# Epoch 3/20
# 30/30 [==============================] - 1s 41ms/step - loss: 0.2355 - binary_accuracy: 0.9250 - val_loss: 0.2868 - val_binary_accuracy: 0.8885
# Epoch 4/20
# 30/30 [==============================] - 2s 52ms/step - loss: 0.1815 - binary_accuracy: 0.9425 - val_loss: 0.2873 - val_binary_accuracy: 0.8851
# Epoch 5/20
# 30/30 [==============================] - 2s 69ms/step - loss: 0.1488 - binary_accuracy: 0.9527 - val_loss: 0.3008 - val_binary_accuracy: 0.8790
# Epoch 6/20
# 30/30 [==============================] - 2s 52ms/step - loss: 0.1212 - binary_accuracy: 0.9615 - val_loss: 0.2901 - val_binary_accuracy: 0.8862
# Epoch 7/20
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0981 - binary_accuracy: 0.9717 - val_loss: 0.3117 - val_binary_accuracy: 0.8852
# Epoch 8/20
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0789 - binary_accuracy: 0.9783 - val_loss: 0.3709 - val_binary_accuracy: 0.8757
# Epoch 9/20
# 30/30 [==============================] - 1s 51ms/step - loss: 0.0633 - binary_accuracy: 0.9842 - val_loss: 0.3732 - val_binary_accuracy: 0.8794
# Epoch 10/20
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0506 - binary_accuracy: 0.9883 - val_loss: 0.4128 - val_binary_accuracy: 0.8760
# Epoch 11/20
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0431 - binary_accuracy: 0.9901 - val_loss: 0.4099 - val_binary_accuracy: 0.8776
# Epoch 12/20
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0303 - binary_accuracy: 0.9947 - val_loss: 0.5615 - val_binary_accuracy: 0.8592
# Epoch 13/20
# 30/30 [==============================] - 2s 64ms/step - loss: 0.0255 - binary_accuracy: 0.9959 - val_loss: 0.5225 - val_binary_accuracy: 0.8712
# Epoch 14/20
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0197 - binary_accuracy: 0.9968 - val_loss: 0.5114 - val_binary_accuracy: 0.8740
# Epoch 15/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0175 - binary_accuracy: 0.9967 - val_loss: 0.5375 - val_binary_accuracy: 0.8727
# Epoch 16/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0106 - binary_accuracy: 0.9988 - val_loss: 0.6047 - val_binary_accuracy: 0.8568
# Epoch 17/20
# 30/30 [==============================] - 1s 38ms/step - loss: 0.0084 - binary_accuracy: 0.9993 - val_loss: 0.6406 - val_binary_accuracy: 0.8691
# Epoch 18/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0063 - binary_accuracy: 0.9996 - val_loss: 0.6741 - val_binary_accuracy: 0.8582
# Epoch 19/20
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0043 - binary_accuracy: 0.9998 - val_loss: 0.6972 - val_binary_accuracy: 0.8691
# Epoch 20/20
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0040 - binary_accuracy: 0.9996 - val_loss: 0.7264 - val_binary_accuracy: 0.8677

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'val_loss', 'val_binary_accuracy'])

# %%
# Plotting losses
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g', label="Training Loss")
plt.plot(epochs, val_loss_values, 'b', label="Validation Loss")

plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss Value')
plt.legend()

plt.show()

# %%
# Training and Validation Accuracy

acc_values = history_dict['binary_accuracy']
val_acc_values = history_dict['val_binary_accuracy']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, acc_values, 'g', label="Training Accuracy")
plt.plot(epochs, val_acc_values, 'b', label="Validation Accuracy")

plt.title('Training and Validation Accuraccy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
model.fit(
    partial_X_train,
    partial_y_train,
    epochs=3,
    batch_size=512,
    validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/3
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0041 - binary_accuracy: 0.9993 - val_loss: 0.7598 - val_binary_accuracy: 0.8662
# Epoch 2/3
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0016 - binary_accuracy: 0.9999 - val_loss: 0.8451 - val_binary_accuracy: 0.8661
# Epoch 3/3
# 30/30 [==============================] - 1s 42ms/step - loss: 0.0045 - binary_accuracy: 0.9987 - val_loss: 0.8425 - val_binary_accuracy: 0.8671

# %%
# Making Predictions for testing data
np.set_printoptions(suppress=True)
result = model.predict(X_test)
# Out:
# 782/782 [==============================] - 2s 2ms/step

# %%
result
# Out:
# array([[0.00353112],
#        [1.        ],
#        [0.9983017 ],
#        ...,
#        [0.00315275],
#        [0.00745248],
#        [0.97512645]], dtype=float32)

# %%
y_pred = np.zeros(len(result))
for i, score in enumerate(result):
    y_pred[i] = np.round(score)

# %%
mae = metrics.mean_absolute_error(y_pred, y_test)
mae
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.15052>
